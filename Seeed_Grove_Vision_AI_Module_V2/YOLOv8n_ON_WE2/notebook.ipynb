# %% [markdown]
# # Based off of
# # https://github.com/HimaxWiseEyePlus/YOLO11_on_WE2/blob/main/examples/YOLO11_on_WE2_Tutorial.ipynb

# %%
# !git clone https://github.com/kris-himax/ultralytics
# %cd ultralytics
# %pip install .
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce GTX 1070, 8106MiB)
# Setup complete ✅ (8 CPUs, 15.5 GB RAM, 134.3/218.5 GB disk)

# %%
# %pip install tf_keras
# Out:
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached setuptools-79.0.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 29.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.7 MB/s eta 0:00:00
# ...

# %%
# !yolo export model=yolov8n.pt format=tflite int8=True no_post=False imgsz=320
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.10 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 84, 2100) (6.2 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 1.0s, saved as 'yolov8n.onnx' (12.1 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
# TensorFlow SavedModel: WARNING ⚠️ >300 images recommended for INT8 calibration, found 4 images.
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.22.3...
# TensorFlow SavedModel: export success ✅ 37.0s, saved as 'yolov8n_saved_model' (40.2 MB)
#
# ...

# %%
# !pip3 install ethos-u-vela
# !curl https://raw.githubusercontent.com/HimaxWiseEyePlus/ML_FVP_EVALUATION/main/vela/himax_vela.ini
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 32.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.2.10
#     Uninstalling flatbuffers-25.2.10:
#       Successfully uninstalled flatbuffers-25.2.10
# ...
# ; file: my_vela_cfg.ini ; -----------------------------------------------------------------------------
# ; Vela configuration file ; -----------------------------------------------------------------------------
# ; System Configuration
#
# ; My_Sys_Cfg
# [System_Config.My_Sys_Cfg]
# core_clock=400e6
# axi0_port=Sram
# axi1_port=OffChipFlash
# Sram_clock_scale=1.0
# Sram_burst_length=32
# Sram_read_latency=16
# Sram_write_latency=16
# Dram_clock_scale=0.75
# Dram_burst_length=128
# Dram_read_latency=500
# Dram_write_latency=250
# OnChipFlash_clock_scale=0.25
# OffChipFlash_clock_scale=0.015625
# OffChipFlash_burst_length=32
# ...

# %%
# !cd
# !vela --accelerator-config ethos-u55-64 --config /home/admin/Desktop/capstone/YOLOv8n_ON_WE2/himax_vela.ini --system-config My_Sys_Cfg --memory-mode My_Mem_Mode_Parent --output-dir ./ ./yolov8n_saved_model/yolov8n_full_integer_quant.tflite
# Out:
# /bin/bash: line 1: vela: command not found

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=C:\Users\Rio\Downloads\YOLOv8_on_WE2\ultralytics\yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.10 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 c:\Users\Rio\Downloads\YOLOv8_on_WE2\ultralytics\zidane.jpg: 384x640 2 persons, 1 tie, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# Out:
# 100%|██████████| 780M/780M [00:07<00:00, 116MB/s]

# %%
# !cd
# !mkdir datasets
# !tar -xf tmp.zip -C datasets && del tmp.zip
# Out:
# c:\Users\Rio\Downloads\YOLOv8_on_WE2\ultralytics
# A subdirectory or file datasets already exists.

# %%
# !yolo val model=C:\Users\Rio\Downloads\YOLOv8_on_WE2\ultralytics\yolov8n.pt data=coco8.yaml
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.10 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#                    all          4         17      0.621      0.833      0.888       0.63
#                 person          3         10      0.721        0.5      0.519      0.269
#                    dog          1          1       0.37          1      0.995      0.597
#                  horse          1          2      0.751          1      0.995      0.631
#               elephant          1          2      0.505        0.5      0.828      0.394
#               umbrella          1          1      0.564          1      0.995      0.995
#           potted plant          1          1      0.814          1      0.995      0.895
# Speed: 1.5ms preprocess, 46.3ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# ...

# %%
#@title Select YOLO11 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# COMET WARNING: comet_ml.init() is deprecated and will be removed soon. Please use comet_ml.login()
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# COMET INFO: Valid Comet API Key saved in /home/admin/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
import comet_ml
# !yolo train model=yolov8n.pt data="/home/admin/Downloads/stc_dataset/stc.yaml" epochs=15 imgsz=320
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.53 🚀 Python-3.10.10 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# ...
